# %%
# Theory Questions:
# Question 1: What is the difference between a function and a method in Python?
# Answer 1: Function: It is a block of reusable code that operates independently which can be called by its name. It is not tied to any class or an object. While defining a function def keyword is used, and functions can take any number of arguments and return values.
# Method: It is a function which is defined within a class and is associated with objects of that class. A method when it’s called, it is called on an instance of the class, and the method typically operates on the data within that instance. They take the instance itself (usually named self) as their first parameter automatically, which allows them to access and modify the object’s attributes.
# While both perform similar tasks, functions are independent, and methods are tied to objects or classes.

# Question 2: Explain the concept of function arguments and parameters in Python?
# Answer 2: Parameters: These are the variables listed in a function’s definition which specify what kind of input the function can receive. They act like placeholders for the data that will be passed to the function. When we define a function, we declare its parameters to outline what values the function expects.
# Arguments: They are the actual values or data which we provide when we call the function. These values are passed to the function and assigned to the corresponding parameters, which allows the function to perform operations on them.
# Types of Arguments and Parameters:
# Positional Arguments: They are passed to the function in the same order as we define the parameters. Which parameter they correspond to is determined by their position in the function call.
# Keyword Arguments: When we explicitly name the parameter and assign a value, regardless of the order these are known as keyword arguments.
# Default Parameters: Parameters can have default values, which are used if no corresponding argument is provided during the function call.
# Variable-Length Arguments: Functions are allowed to accept an arbitrary number of positional (*args) or keyword (**kwargs) arguments which enables flexibility when we don’t know the exact number of inputs.

# Question 3: What are the different ways to define and call a function in Python?
# Answer 3: There are various ways to define and call functions, it depends on the requirements of the task.
# An overview of the different methods:
# Regular Functions:
# A function is defined using the def keyword, followed by the function name and a set of parameters (if any). It is called by using its name followed by parentheses, optionally passing arguments.
# Function with Default Parameters:
# It can be defined with default parameter values. If no argument is passed for a parameter, the default value is used. When calling the function, you can either omit the arguments with default values or provide them to override the defaults.
# Keyword Arguments:
# When calling a function, we can specify which parameter to assign a value to by using the parameter’s name (keyword arguments), which allows you to pass arguments in any order.
# Variable-Length Arguments (*args and **kwargs):
# Functions can be defined to accept an arbitrary number of positional arguments using *args, and an arbitrary number of keyword arguments using **kwargs. This allows the function to handle varying amounts of input when called.
# Lambda Functions (Anonymous Functions):
# Lambda functions are one-liners, defined using the lambda keyword. They don’t require a def statement and are typically used for small, simple operations. Lambda functions are called in the same way as regular functions.
# Nested Functions:
# Functions can be defined within other functions. These inner functions are only accessible from within the outer function. You call the outer function, and the inner function may be invoked within its scope.
# Recursive Functions:
# A function can call itself within its definition to solve a problem in a recursive manner. Recursive functions need a base case to prevent infinite recursion.
# Method Calls (Object-Oriented):
# Methods are functions defined within a class. You call them by creating an instance of the class and then invoking the method on that instance. Some methods can be called on the class itself if they are defined as class methods.
# Functions as Arguments (Higher-Order Functions):
# Functions can be passed as arguments to other functions or returned as values from other functions. This allows for more functional programming approaches.

# Question 4: What is the purpose of the return statement in a Python function?
# Answer 4: The return statement in a Python function is used to exit the function and send back a value (or values) to the caller. It serves two main purposes:
# Exiting the function: When the return statement is encountered, the function stops executing, and control is passed back to the code that called the function.
# Returning a value: It can be used to return a value (or multiple values as a tuple) to the caller. If no value is provided, the function returns none by default.
# For example:
def add (a, b):
    return a + b
result = add (3, 4)
print (result)

# Question 5: What are iterators in Python and how do they differ from iterables?
# Answer 5: An iterable is any object in Python that can be looped over, such as lists, strings, or sets. It has an iter () method that returns an iterator. An iterable allows you to use it with a for loop or functions that work with collections.
# An iterator, on the other hand, is an object that represents a sequence of values. It has both iter () and next () methods. The next () method retrieves the next value in the sequence and raises a StopIteration exception when there are no more items to return.
# Key differences:
# An iterable can be used multiple times in loops, while an iterator can only be used once unless re-created.
# An iterable does not have a next () method, whereas an iterator does.

# Question 6: Explain the concept of generators in Python and how they are defined.
# Answer 6: A generator in Python is a special type of iterator that produces values lazily, one at a time, instead of storing them all in memory. Generators are defined using the yield keyword. When called, a generator function returns a generator object, which can be iterated over.
# Key points:
# Yield pauses the function, saving its state, and resumes when needed.
# Generators are memory-efficient, ideal for large or infinite sequences.
# They implement both iter () and next () methods automatically.


# Question 7: What are the advantages of using generators over regular functions?
# Answer 7: Generators offer several advantages over regular functions:
# Memory efficiency: Generators yield one item at a time, which is more memory-efficient, especially when handling large datasets, as they don't store all items in memory at once.
# Lazy evaluation: Values are produced only when needed, which helps in working with infinite sequences or large data streams without overwhelming memory.
# Improved performance: Since values are generated on the fly, generators reduce the overhead of creating and storing large data structures, leading to faster execution in certain scenarios.
# State retention: Generators automatically maintain their state between yield calls, making them easier to use for tasks involving sequences or maintaining state over iterations.
# Simpler syntax: Generators are more concise than manually implementing an iterator class, making code easier to write and maintain.

# Question 8: What is a lambda function in Python and when is it typically used?
# Answer 8: A lambda function in Python is an anonymous, one-liner function defined using the lambda keyword. It can have any number of inputs but only a single expression, which is evaluated and returned. Unlike regular functions defined with def, lambda functions don’t need a name and are often used in situations where a simple function is required temporarily.
# Typical Uses of Lambda Functions:
# Short, simple operations: They are useful for quick operations that can be written in a single line, such as in small calculations or conditional logic.
# As arguments to higher-order functions: They are often used with functions like map (), filter (), and sorted (), where passing a full function definition would be overkill.
# In data structures: Lambda functions can be used for defining small, throwaway functions inside list comprehensions or similar structures.

# Question 9: Explain the purpose and usage of the `map () ` function in Python.
# Answer 9: The map () function in Python is used to apply a given function to all items in an iterable (such as a list, tuple, etc.) and return a map object (which is an iterator). It allows you to transform the elements of an iterable in a concise and efficient way without needing an explicit loop.
# Purpose:
# The primary purpose of map () is to process each element of an iterable through a function, applying the same operation to all elements. This is especially useful for transforming or modifying data collections.
# Usage:
# Syntax: map (function, iterable, ...)
# function: A function that takes one or more arguments.
# Iterable: One or more iterable objects. If there are multiple iterables, the function must take as many arguments as there are iterables.
# The map () function returns a map object, which can be converted to a list or another data type.
# Example Use Cases:
# Transforming a list: Apply a function to each element in a list (e.g., squaring each number).
# Combining multiple iterables: Use a function that processes multiple iterables in parallel (e.g., adding corresponding elements from two lists).
# Map () is typically used when you need to apply a function to every item of a collection in a compact and readable way.

# Question 10: What is the difference between `map () `, `reduce () `, and `filter () ` functions in Python?
# Answer 10: Here’s a concise comparison of map (), filter (), and reduce ():
# Map ():
# Purpose: Applies a function to each item in an iterable, transforming each element.
# Result: An iterable of the same length as the input.
# Filter ():
# Purpose: Filters items in an iterable based on a condition (function that returns True or False).
# Result: An iterable with only elements that satisfy the condition.
# Reduce ():
# Purpose: Applies a function cumulatively to reduce an iterable to a single value.
# Result: A single aggregated result.
# Key Differences:
# Map (): Transforms all items.
# Filter (): Selects specific items.
# Reduce (): Combines all items into one value.

# Question 11: Using pen & Paper write the internal mechanism for sum operation using reduce function on this given list: [47,11,42,13];
# Answer 11: To illustrate the internal mechanism of the sum operation using the reduce () function on the list [47, 11, 42, 13], we can break it down step by step.
# Step-by-Step Process
# Import (reduce): First, we need to import the reduce function from the functools module.
# from functools import reduce
# Addition function: We define a simple function that takes two arguments and returns their sum.
# def add (x, y):
    # return x + y
# Initialize the list: The list we will use is:
# numbers = [47, 11, 42, 13]
# Apply reduce (): Now, we use the reduce () function to sum the elements of the list.
# result = reduce (add, numbers)
# Out:
# 7

# %% [markdown]
# ![IMG_0968 (1).jpg](data:image/jpeg;base64,...)

# %%
# Practical Questions:

# Question 1: Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
# Answer 1: Python function that takes a list of numbers as input and returns the sum of all even numbers in that list:
def sum_of_even_numbers(numbers):
    return sum (num for num in numbers if num % 2 == 0)
# Example usage
numbers = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(numbers)
print (result)

# Question 2: Create a Python function that accepts a string and returns the reverse of that string.
# Answer 2:
def reverse_string (s):
    return s [::-1]
# Example usage
input_string = "Hello, World!"
result = reverse_string (input_string)
print(result)

# Question 3: Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
# Answer 3:
def square_numbers (numbers):
    return [num ** 2 for num in numbers]
# Example usage
input_list = [1, 2, 3, 4, 5]
result = square_numbers(input_list)
print (result)

# Question 4: Write a Python function that checks if a given number is prime or not from 1 to 200.
# Answer 4:
def is_prime (n):
    if n <= 1:
        return False
    for i in range (2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True
# Example usage
for number in range (1, 101):
    if is_prime (number):
        print (f"{number} is a prime number.")

# Question 5: Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
# Answer 5:
class Fibonacciiterator:
    def __init__ (self, n):
        self.n = n
        self.a, self.b = 0, 1
        self.count = 0
    def __iter__ (self):
        return self
    def __next__ (self):
        if self.count < self.n:
            next_value = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return next_value
        else:
            raise StopIteration
# Example usage
fibonacci_terms = 10 # Specify the number of terms
fibonacci_sequence = Fibonacciiterator(fibonacci_terms)
for number in fibonacci_sequence:
    print (number)

# Question 6: Write a generator function in Python that yields the powers of 2 up to a given exponent.
# Answer 6:
def powers_of_two (exponent):
    for i in range (exponent + 1):
        yield 2 ** i
# Example usage
exponent = 5 # Specify the maximum exponent
for power in powers_of_two(exponent):
    print(power)

# Question 7: Implement a generator function that reads a file line by line and yields each line as a string.
# Answer 7:
def read_file_line_by_line(file_path):
    """Generator function to read a file line by line."""
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.strip()  # Yield each line, stripping newline characters
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except IOError:
        print(f"Error: An error occurred while reading the file '{file_path}'.")

# Example usage
file_path = 'example.txt'  # Specify the path to your file
for line in read_file_line_by_line(file_path):
    print(line)

# Question 8: Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
# Answer 8: Sample list of tuples
data = ((1, 'banana'), (3, 'Orange'), (2, 'Cow'), (4, 'yuvraj'))
# Sorting the list of tuples based on the second element
sorted_data = sorted (data, key=lambda x: x[1])
# Example usage
print (sorted_data)

# Question 9: Write a Python program that uses `map () ` to convert a list of temperatures from Celsius to Fahrenheit.
# Answer 9: Function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit (celsius):
    return (celsius * 9/5) + 32
# List of temperatures in Celsius
celsius_temperatures = [0, 20, 37, 100]
# Using map () to convert to Fahrenheit
fahrenheit_temperatures = list (map (celsius_to_fahrenheit, celsius_temperatures))
# Example usage
print (fahrenheit_temperatures)

# Question 10: Create a Python program that uses `filter () ` to remove all the vowels from a given string.
# Answer 10: Function to check if a character is not a vowel
def is_not_vowel(char):
    return char.lower() not in 'aeiou'
# Input string
input_string = "Hello, World!"
# Using filter() to remove vowels
filtered_string = ''.join(filter(is_not_vowel, input_string))
# Example usage
print(filtered_string)

# Question 11: Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# Order Number	Book Title and Author	Quantity	Price per Item
# 34587	Learning Python, Mark Lutz	4	40.95
# 98762	Programming Python, Mark Lutz	5	56.80
# 77226	Head First Python, Paul Barry	3	32.95
# 88112	Einfūhrung in Python3, Bernd Klein	3	24.99
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.
# Write a Python program using lambda and map.

# Answer 11: List of orders
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einfūhrung in Python3, Bernd Klein", 3, 24.99]
]

# Function to calculate total value with potential adjustment
def calculate_order_value(order):
    order_number, _, quantity, price_per_item = order
    total_value = quantity * price_per_item
    if total_value < 100:
        total_value += 10 # Add 10 € if total value is less than 100
    return (order_number, total_value)

# Use map to apply the function to each order
order_values = list (map (calculate_order_value, orders))

# Example usage
print (order_values)
